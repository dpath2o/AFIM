# %%
import os
import pprint
from datetime import date
from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt

# %%
pp     = pprint.PrettyPrinter(indent=4)
Dbase  = os.path.join('/','Volumes','SEASONG','PHD')
Ddata  = os.path.join(Dbase,'data','satellite','S1')
#Ddata  = os.path.join(Dbase,'data','satellite','S2')
Dsrc   = os.path.join(Dbase,'src','py','BBC_Sentinel1')
Fftprt = os.path.join(Dsrc,'Mawson.geojson')
ftprt  = geojson_to_wkt(read_geojson(Fftprt))
user   = "dpath2o"
pscd   = "bimgaN-6kixce-kixnep"
query_kwargs = {'platformname': 'Sentinel-1',
                'producttype': 'GRD',
                'date': ('2021-07-01T00:00:00.000Z','2021-08-13T23:59:00.000Z' ),
                'instrumentshortname': 'SAR-C SAR',
                'sensoroperationalmode': 'EW'}
#query_kwargs = {'platformname': 'Sentinel-2',
#                'producttype': 'S2MSI1C',
#                'date': ('NOW-14DAYS', 'NOW')}

# %%
api         = SentinelAPI(user, pscd, 'https://scihub.copernicus.eu/dhus')
products    = api.query(ftprt,**query_kwargs)
products_df = api.to_dataframe(products)
for file in products:
    print('Filename {}'.format(products_df.title[file]))
    product_info = api.get_product_odata(file)
    if product_info['Online']:
        print('file is online')
    else:
        print('files is NOT online')
    api.download(file,Ddata)
    pp.pprint(file)
# Out:
# Filename S1B_EW_GRDM_1SDH_20210813T154419_20210813T154523_028229_035E26_0822
# file is online
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=290843505.0), HTML(value='')))
# HBox(children=(HTML(value='MD5 checksumming'), FloatProgress(value=0.0, max=290843505.0), HTML(value='')))
# '4a4bae65-e999-410e-8a02-ab4e48b1471d'
# Filename S1B_EW_GRDM_1SDH_20210813T154523_20210813T154623_028229_035E26_A052
# file is online
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=233090082.0), HTML(value='')))
# HBox(children=(HTML(value='MD5 checksumming'), FloatProgress(value=0.0, max=233090082.0), HTML(value='')))
# '6459e7da-33cc-49d5-b3f3-2358ce3c1a93'
# Filename S1B_EW_GRDM_1SDH_20210809T161714_20210809T161817_028171_035C63_CDA0
# file is online
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sentinelsat/sentinel.py in _check_scihub_response(response, test_json, query_string)
#    1432     try:
# -> 1433         response.raise_for_status()
#    1434         if test_json:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://scihub.copernicus.eu/dhus/odata/v1/Products('191ce2df-d35d-4a98-845e-3f4a4945a66b')/$value
#
# During handling of the above exception, another exception occurred:
#
# ServerError                               Traceback (most recent call last)
# <ipython-input-17-243aa30d4781> in <module>
#      11     else:
#      12         print('files is NOT online')
# ---> 13     api.download(file,Ddata)
#      14     pp.pprint(file)
#
# ~/.local/lib/python3.8/site-packages/sentinelsat/sentinel.py in download(self, id, directory_path, checksum, **kwargs)
#     521
#     522         # An incomplete download triggers the retrieval from the LTA if the product is not online
# --> 523         is_online = not self.trigger_offline_retrieval(id)
#     524         if not is_online:
#     525             raise LTATriggered(id)
#
# ~/.local/lib/python3.8/site-packages/sentinelsat/sentinel.py in trigger_offline_retrieval(self, uuid)
#     643             self.logger.error(msg)
#     644             raise ServerError(msg, r)
# --> 645         _check_scihub_response(r, test_json=False)
#     646
#     647     def download_all(
#
# ~/.local/lib/python3.8/site-packages/sentinelsat/sentinel.py in _check_scihub_response(response, test_json, query_string)
#    1477         elif 500 <= response.status_code < 600 or msg:
#    1478             # 5xx: Server Error
# -> 1479             raise ServerError(msg, response)
#    1480         else:
#    1481             raise SentinelAPIError(msg, response)
#
# ServerError: HTTP status 500 Internal Server Error: UncheckedExecutionException : org.jclouds.http.HttpResponseException: request: POST https://most.onda-dias.eu/v3/auth/tokens HTTP/1.1  [Sensitive data in payload, use jclouds.wire.log.sensitive override to enable logging this data.] failed with response: HTTP/1.1 429 Too Many Requests
