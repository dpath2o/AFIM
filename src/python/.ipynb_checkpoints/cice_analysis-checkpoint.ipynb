# %%
import os
import re
import fnmatch
import glob
import sys
module_path = os.path.abspath(os.path.join('./src/python'))
sys.path.append(module_path)
import afim
import xesmf             as xe
import numpy             as np
import pandas            as pd
import xarray            as xr
import cosima_cookbook   as cc
import matplotlib.pyplot as plt
import cartopy.crs       as ccrs
import cmocean
from dask.distributed import Client
import importlib
# %matplotlib inline

# %%
di  = 14
hpd = 24
ti0 = (di-1)*hpd
tiN = di*hpd

# %%
ICE = xr.open_dataset('/g/data/jk72/da1339/cice-dirs/runs/afim_0p1/history/iceh.2005-01-14.nc')
ICE.aice.plot(figsize=(20,10))

# %%
ATM = xr.open_dataset('/g/data/jk72/da1339/cice-dirs/input/AFIM/forcing/0p1/8XDAILY/JRA55_03hr_forcing_tx1_2005.nc',chunks={'time':'1'})
ATM.airtmp.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
ATM.dlwsfc.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
ATM.glbrad.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
ATM.spchmd.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
ATM.ttlpcp.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
ATM.wndewd.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
ATM.wndnwd.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))

# %%
OCN = xr.open_dataset('/g/data/jk72/da1339/cice-dirs/input/AFIM/forcing/0p1/daily/AC-OM2-01_ocn_frcg_CICE6_2005.nc',chunks={'time':'1'})
OCN.T.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
OCN.S.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
OCN.hblt.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
OCN.U.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
OCN.V.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
OCN.dhdx.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
OCN.dhdy.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
OCN.qdp.isel(time=slice(ti0,tiN)).mean(dim='time').isel(nj=slice(0,1000)).plot(figsize=(20,10))
